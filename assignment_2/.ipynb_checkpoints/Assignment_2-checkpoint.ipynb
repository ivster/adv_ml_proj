# %% [markdown]
# Your final report should be written up in a Jupyter notebook.  It should be posted to a public Github repo as an ipynb  submitted to this assignment via courseworks.  Please include the link to your Github repo in this ipynb file.
#
# Use the Covid Hackathon ipynb notebook from the Week 7 folder to import and train test split data.

# %%
# Connect to google drive
import os
from google.colab import drive
drive.mount('/content/drive')

# content in your drive is now available via "/content/drive/My Drive"
# Out:
# Mounted at /content/drive

# %%
# Import data and unzip files to folder
# !unzip /content/drive/MyDrive/covid_radiography_data/COVID-19_Radiography_Dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7924.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7925.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7926.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7927.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7928.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7929.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-793.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7930.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7931.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7932.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7933.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7934.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7935.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7936.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7937.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7938.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7939.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-794.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7940.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7941.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7942.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7943.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7944.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7945.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7946.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7947.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7948.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7949.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-795.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7950.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7951.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7952.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7953.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7954.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7955.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7956.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7957.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7958.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7959.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-796.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7960.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7961.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7962.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7963.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7964.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7965.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7966.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7967.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7968.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7969.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-797.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7970.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7971.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7972.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7973.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7974.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7975.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7976.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7977.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7978.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7979.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-798.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7980.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7981.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7982.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7983.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7984.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7985.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7986.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7987.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7988.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7989.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-799.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7990.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7991.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7992.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7993.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7994.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7995.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7996.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7997.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7998.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-7999.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-80.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-800.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8000.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8001.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8002.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8003.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8004.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8005.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8006.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8007.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8008.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8009.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-801.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8010.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8011.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8012.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8013.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8014.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8015.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8016.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8017.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8018.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8019.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-802.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8020.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8021.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8022.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8023.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8024.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8025.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8026.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8027.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8028.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8029.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-803.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8030.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8031.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8032.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8033.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8034.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8035.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8036.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8037.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8038.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8039.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-804.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8040.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8041.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8042.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8043.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8044.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8045.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8046.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8047.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8048.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8049.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-805.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8050.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8051.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8052.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8053.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8054.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8055.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8056.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8057.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8058.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8059.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-806.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8060.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8061.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8062.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8063.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8064.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8065.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8066.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8067.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8068.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8069.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-807.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8070.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8071.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8072.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8073.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8074.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8075.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8076.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8077.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8078.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8079.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-808.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8080.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8081.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8082.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8083.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8084.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8085.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8086.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8087.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8088.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8089.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-809.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8090.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8091.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8092.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8093.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8094.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8095.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8096.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8097.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8098.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8099.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-81.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-810.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8100.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8101.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8102.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8103.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8104.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8105.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8106.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8107.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8108.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8109.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-811.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8110.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8111.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8112.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8113.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8114.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8115.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8116.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8117.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8118.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8119.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-812.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8120.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8121.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8122.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8123.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8124.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8125.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8126.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8127.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8128.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8129.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-813.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8130.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8131.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8132.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8133.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8134.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8135.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8136.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8137.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8138.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8139.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-814.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8140.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8141.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8142.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8143.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8144.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8145.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8146.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8147.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8148.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8149.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-815.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8150.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8151.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8152.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8153.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8154.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8155.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8156.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8157.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8158.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8159.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-816.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8160.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8161.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8162.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8163.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8164.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8165.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8166.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8167.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8168.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8169.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-817.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8170.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8171.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8172.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8173.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8174.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8175.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8176.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8177.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8178.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8179.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-818.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8180.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8181.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8182.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8183.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8184.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8185.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8186.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8187.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8188.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8189.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-819.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8190.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8191.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8192.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8193.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8194.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8195.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8196.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8197.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8198.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8199.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-82.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-820.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8200.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8201.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8202.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8203.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8204.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8205.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8206.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8207.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8208.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8209.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-821.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8210.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8211.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8212.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8213.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8214.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8215.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8216.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8217.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8218.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8219.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-822.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8220.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8221.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8222.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8223.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8224.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8225.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8226.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8227.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8228.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8229.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-823.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8230.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8231.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8232.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8233.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8234.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8235.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8236.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8237.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8238.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8239.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-824.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8240.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8241.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8242.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8243.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8244.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8245.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8246.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8247.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8248.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8249.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-825.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8250.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8251.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8252.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8253.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8254.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8255.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8256.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8257.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8258.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8259.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-826.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8260.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8261.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8262.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8263.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8264.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8265.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8266.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8267.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8268.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8269.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-827.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8270.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8271.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8272.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8273.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8274.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8275.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8276.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8277.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8278.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8279.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-828.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8280.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8281.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8282.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8283.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8284.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8285.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8286.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8287.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8288.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8289.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-829.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8290.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8291.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8292.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8293.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8294.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8295.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8296.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8297.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8298.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8299.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-83.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-830.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8300.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8301.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8302.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8303.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8304.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8305.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8306.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8307.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8308.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8309.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-831.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8310.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8311.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8312.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8313.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8314.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8315.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8316.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8317.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8318.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8319.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-832.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8320.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8321.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8322.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8323.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8324.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8325.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8326.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8327.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8328.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8329.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-833.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8330.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8331.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8332.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8333.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8334.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8335.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8336.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8337.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8338.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8339.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-834.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8340.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8341.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8342.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8343.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8344.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8345.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8346.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8347.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8348.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8349.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-835.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8350.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8351.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8352.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8353.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8354.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8355.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8356.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8357.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8358.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8359.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-836.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8360.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8361.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8362.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8363.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8364.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8365.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8366.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8367.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8368.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8369.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-837.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8370.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8371.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8372.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8373.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8374.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8375.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8376.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8377.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8378.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8379.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-838.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8380.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8381.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8382.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8383.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8384.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8385.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8386.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8387.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8388.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8389.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-839.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8390.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8391.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8392.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8393.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8394.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8395.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8396.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8397.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8398.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8399.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-84.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-840.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8400.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8401.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8402.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8403.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8404.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8405.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8406.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8407.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8408.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8409.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-841.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8410.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8411.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8412.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8413.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8414.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8415.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8416.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8417.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8418.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8419.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-842.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8420.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8421.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8422.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8423.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8424.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8425.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8426.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8427.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8428.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8429.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-843.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8430.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8431.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8432.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8433.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8434.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8435.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8436.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8437.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8438.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8439.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-844.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8440.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8441.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8442.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8443.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8444.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8445.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8446.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8447.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8448.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8449.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-845.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8450.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8451.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8452.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8453.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8454.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8455.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8456.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8457.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8458.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8459.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-846.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8460.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8461.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8462.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8463.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8464.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8465.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8466.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8467.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8468.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8469.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-847.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8470.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8471.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8472.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8473.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8474.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8475.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8476.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8477.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8478.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8479.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-848.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8480.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8481.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8482.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8483.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8484.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8485.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8486.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8487.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8488.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8489.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-849.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8490.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8491.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8492.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8493.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8494.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8495.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8496.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8497.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8498.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8499.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-85.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-850.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8500.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8501.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8502.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8503.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8504.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8505.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8506.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8507.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8508.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8509.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-851.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8510.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8511.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8512.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8513.png
#   inflating: COVID-19_Radiography_Dataset/Normal/masks/Normal-8514.png
# ...
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-839.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-84.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-840.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-841.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-842.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-843.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-844.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-845.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-846.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-847.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-848.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-849.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-85.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-850.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-851.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-852.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-853.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-854.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-855.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-856.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-857.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-858.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-859.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-86.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-860.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-861.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-862.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-863.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-864.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-865.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-866.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-867.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-868.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-869.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-87.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-870.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-871.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-872.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-873.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-874.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-875.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-876.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-877.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-878.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-879.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-88.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-880.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-881.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-882.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-883.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-884.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-885.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-886.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-887.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-888.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-889.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-89.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-890.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-891.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-892.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-893.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-894.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-895.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-896.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-897.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-898.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-899.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-9.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-90.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-900.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-901.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-902.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-903.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-904.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-905.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-906.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-907.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-908.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-909.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-91.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-910.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-911.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-912.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-913.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-914.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-915.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-916.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-917.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-918.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-919.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-92.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-920.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-921.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-922.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-923.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-924.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-925.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-926.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-927.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-928.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-929.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-93.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-930.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-931.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-932.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-933.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-934.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-935.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-936.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-937.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-938.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-939.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-94.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-940.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-941.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-942.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-943.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-944.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-945.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-946.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-947.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-948.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-949.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-95.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-950.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-951.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-952.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-953.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-954.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-955.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-956.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-957.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-958.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-959.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-96.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-960.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-961.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-962.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-963.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-964.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-965.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-966.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-967.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-968.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-969.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-97.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-970.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-971.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-972.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-973.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-974.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-975.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-976.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-977.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-978.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-979.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-98.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-980.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-981.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-982.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-983.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-984.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-985.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-986.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-987.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-988.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-989.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-99.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-990.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-991.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-992.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-993.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-994.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-995.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-996.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-997.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-998.png
#   inflating: COVID-19_Radiography_Dataset/Viral Pneumonia/masks/Viral Pneumonia-999.png

# %%
# Load libraries and then download data

import sys
import time
import cv2
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
import os
import zipfile


from tensorflow.python.keras.utils import np_utils
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.python.keras.layers.convolutional import Conv2D, MaxPooling2D 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from tensorflow.keras.applications import VGG19, ResNet50, InceptionV3

# %%
# Extracting all filenames iteratively
base_path = 'COVID-19_Radiography_Dataset'
categories = ['COVID/images', 'Normal/images', 'Viral Pneumonia/images']

# load file names to fnames list object
fnames = []
for category in categories:
    image_folder = os.path.join(base_path, category)
    file_names = os.listdir(image_folder)
    full_path = [os.path.join(image_folder, file_name) for file_name in file_names]
    fnames.append(full_path)

print('number of images for each category:', [len(f) for f in fnames])
print(fnames[0:2]) #examples of file names
# Out:
# number of images for each category: [3616, 10192, 1345]
# [['COVID-19_Radiography_Dataset/COVID/images/COVID-2579.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1097.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3339.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1157.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2970.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3183.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2800.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-696.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-997.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3148.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3165.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3585.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-103.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3342.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-140.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2359.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2961.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3399.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2989.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1218.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2160.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-82.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2361.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1399.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2481.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2947.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1505.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1344.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2832.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2827.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-36.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2079.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3601.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3418.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2771.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2727.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2954.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1370.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2825.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2578.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-531.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-739.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1739.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3102.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3517.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1267.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-130.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3198.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-200.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-444.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1113.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2702.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1693.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-3046.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-744.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-278.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-60.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1476.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1383.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1252.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-791.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1257.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-2245.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-1221.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-871.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-501.png', 'COVID-19_Radiography_Dataset/COVID/images/COVID-607.png', ...

# %%
#Reduce number of images to first 1345 for each category
fnames[0]=fnames[0][0:1344]
fnames[1]=fnames[1][0:1344]
fnames[2]=fnames[2][0:1344]

# %%
# Import image, load to array of shape height, width, channels, then min/max transform.
# Write preprocessor that will match up with model's expected input shape.
from keras.preprocessing import image
import numpy as np
from PIL import Image

def preprocessor(img_path):
        img = Image.open(img_path).convert("RGB").resize((192,192)) # import image, make sure it's RGB and resize to height and width you want.
        img = (np.float32(img)-1.)/(255-1.) # min max transformation
        img=img.reshape((192,192,3)) # Create final shape as array with correct dimensions for Keras
        return img



#Try on single flower file (imports file and preprocesses it to data with following shape)
preprocessor('COVID-19_Radiography_Dataset/COVID/images/COVID-2273.png').shape
# Out:
# (192, 192, 3)

# %%
#Import image files iteratively and preprocess them into array of correctly structured data

# Create list of file paths
image_filepaths=fnames[0]+fnames[1]+fnames[2]

# Iteratively import and preprocess data using map function

# map functions apply your preprocessor function one step at a time to each filepath
preprocessed_image_data=list(map(preprocessor,image_filepaths ))

# Object needs to be an array rather than a list for Keras (map returns to list object)
X= np.array(preprocessed_image_data) # Assigning to X to highlight that this represents feature input data for our model

# %%
len(image_filepaths)
# Out:
# 4032

# %%
print(len(X) ) #same number of elements as filenames
print(X.shape ) #dimensions now 192,192,3 for all images
print(X.min().round() ) #min value of every image is zero
print(X.max() ) #max value of every image is one
# Out:
# 4032
# (4032, 192, 192, 3)
# -0.0
# 1.0

# %%
len(fnames[2])
# Out:
# 1344

# %%
# Create y data made up of correctly ordered labels from file folders
from itertools import repeat

# Recall that we have five folders with the following number of images in each folder 
#...corresponding to each flower type

print('number of images for each category:', [len(f) for f in fnames])
covid=list(repeat("COVID", 1344))
normal=list(repeat("NORMAL", 1344))
pneumonia=list(repeat("PNEUMONIA", 1344))

#combine into single list of y labels
y_labels = covid+normal+pneumonia

#check length, same as X above
print(len(y_labels) )

# Need to one hot encode for Keras.  Let's use Pandas

import pandas as pd
y=pd.get_dummies(y_labels)

display(y)
# Out:
# number of images for each category: [1344, 1344, 1344]
# 4032
#       COVID  NORMAL  PNEUMONIA
# 0         1       0          0
# 1         1       0          0
# 2         1       0          0
# 3         1       0          0
# 4         1       0          0
# ...     ...     ...        ...
# 4027      0       0          1
# 4028      0       0          1
# 4029      0       0          1
# 4030      0       0          1
# 4031      0       0          1
#
# [4032 rows x 3 columns]

# %%
# ======Train test split resized images (Hackathon Note!! Use same train test split to be able to submit predictions to leaderboard!)=======================================
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.32, random_state = 1987)


X_test.shape, y_test.shape
# Out:
# ((1291, 192, 192, 3), (1291, 3))

# %%
#Clear objects from memory
del(X)
del(y)
del(preprocessed_image_data)

# %%
#Save data to be able to reload quickly if memory crashes or if you run Runtime>Restart Runtime
import pickle

# Open a file and use dump()
with open('X_train.pkl', 'wb') as file:
    # A new file will be created
    pickle.dump(X_train, file)

#Save data
import pickle

# Open a file and use dump()
with open('X_test.pkl', 'wb') as file:
    # A new file will be created
    pickle.dump(X_test, file)

#Save data
import pickle

# Open a file and use dump()
with open('y_train.pkl', 'wb') as file:
    # A new file will be created
    pickle.dump(y_train, file)


# Open a file and use dump()
with open('y_test.pkl', 'wb') as file:
    # A new file will be created
    pickle.dump(y_test, file)

# %%
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_train.pkl', 'rb') as file:
    # Call load method to deserialze
    X_train = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)

# %% [markdown]
# # Visualize images that demonstrate when x-rays demonstrate Covid Positivity and when they do not (You can present visuals of each category in the data if you would like to.).

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np
import random

im1 =preprocessor(fnames[0][0])
im2 =preprocessor(fnames[0][1])
im3 =preprocessor(fnames[1][1])
im4 =preprocessor(fnames[1][1])

fig = plt.figure(figsize=(4., 4.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(2, 2),  # creates 2x2 grid of axes
                 axes_pad=0.25,  # pad between axes in inch.
                 )

for ax, im in zip(grid, [im1, im2, im3, im4]):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Discuss the dataset in general terms and describe why building a predictive model using this data might be practically useful.  Who could benefit from a model like this? Explain.

# %% [markdown]
# ### In general, this dataset contains COVID-19 radiography information, specifically showing X-rays demonstrating a person being COVID-positive and negative. By building a predictive model using COVID radiography data, this helps to streamline the COVID-19 diagnosis and treatment process. With a predictive model, this allows for early detection of COVID-19, accurate diagnosis as well as optimal resource allocation. As such, health care professionals would benefit the most from a model like this, streamlining the whole process for future patients and allowing for health care workers to provide treatment as soon as possible.

# %% [markdown]
# # Run at least three prediction models to try to predict x-ray images well. Use transfer learning for at least one of these models

# %% [markdown]
# # Submit your best three models to the leader board for the Covid X-ray Diagnostic AI Model Share competition.

# %%
import tensorflow as tf

# %%
! pip install aimodelshare --upgrade
# Restart session Runtime > Restart runtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting aimodelshare
#   Downloading aimodelshare-0.0.189-py3-none-any.whl (967 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 967.8/967.8 KB 12.5 MB/s eta 0:00:00
# Collecting scipy==1.7.0
#   Downloading scipy-1.7.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 34.1 MB/s eta 0:00:00
# Collecting onnx==1.12.0
#   Downloading onnx-1.12.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 53.6 MB/s eta 0:00:00
# Collecting PyJWT>=2.4.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare) (1.13.1+cu116)
# Collecting importlib-resources==5.10.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Collecting onnxmltools>=1.6.1
#   Downloading onnxmltools-1.11.2-py2.py3-none-any.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 KB 27.9 MB/s eta 0:00:00
# Collecting scikit-learn==1.2.1
#   Downloading scikit_learn-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 79.2 MB/s eta 0:00:00
# Collecting psutil>=5.9.1
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 KB 21.2 MB/s eta 0:00:00
# Collecting keras2onnx>=1.7.0
#   Downloading keras2onnx-1.7.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 KB 9.8 MB/s eta 0:00:00
# Collecting wget==3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow==2.9.2
#   Downloading tensorflow-2.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 2.9 MB/s eta 0:00:00
# Collecting docker==5.0.0
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 KB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.9/dist-packages (from aimodelshare) (1.6.3)
# Collecting botocore==1.29.82
#   Downloading botocore-1.29.82-py3-none-any.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 81.0 MB/s eta 0:00:00
# Collecting onnxconverter-common>=1.7.0
#   Downloading onnxconverter_common-1.13.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.8/83.8 KB 9.3 MB/s eta 0:00:00
# Collecting shortuuid>=1.0.8
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.9/dist-packages (from aimodelshare) (1.3.0)
# Collecting onnxruntime>=1.7.0
#   Downloading onnxruntime-1.14.1-cp39-cp39-manylinux_2_27_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 64.8 MB/s eta 0:00:00
# Requirement already satisfied: protobuf==3.19.6 in /usr/local/lib/python3.9/dist-packages (from aimodelshare) (3.19.6)
# Collecting Pympler==0.9
#   Downloading Pympler-0.9.tar.gz (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 KB 15.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn>=0.11.2 in /usr/local/lib/python3.9/dist-packages (from aimodelshare) (0.11.2)
# Collecting boto3==1.26.69
#   Downloading boto3-1.26.69-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 14.1 MB/s eta 0:00:00
# Collecting tf2onnx
#   Downloading tf2onnx-1.13.0-py3-none-any.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.3/442.3 KB 37.6 MB/s eta 0:00:00
# Collecting skl2onnx>=1.14.0
#   Downloading skl2onnx-1.14.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.0/294.0 KB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from aimodelshare) (2022.6.2)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from aimodelshare) (1.0.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from astunparse==1.6.3->aimodelshare) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse==1.6.3->aimodelshare) (0.38.4)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.9/dist-packages (from botocore==1.29.82->aimodelshare) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.9/dist-packages (from botocore==1.29.82->aimodelshare) (1.26.14)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /usr/local/lib/python3.9/dist-packages (from docker==5.0.0->aimodelshare) (2.25.1)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources==5.10.0->aimodelshare) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.9/dist-packages (from onnx==1.12.0->aimodelshare) (4.5.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.9/dist-packages (from onnx==1.12.0->aimodelshare) (1.22.4)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.9/dist-packages (from pydot==1.3.0->aimodelshare) (3.0.9)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.2.1->aimodelshare) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn==1.2.1->aimodelshare) (3.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (57.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.51.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.15.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (15.0.6.1)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 78.6 MB/s eta 0:00:00
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (23.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (2.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.9.2->aimodelshare) (0.4.0)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 KB 38.5 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 4.8 MB/s eta 0:00:00
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.6 MB/s eta 0:00:00
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime>=1.7.0->aimodelshare) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.9/dist-packages (from seaborn>=0.11.2->aimodelshare) (3.5.3)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.9/dist-packages (from seaborn>=0.11.2->aimodelshare) (1.4.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (4.39.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2022.7.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.10)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.6)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.2.2)
# Building wheels for collected packages: Pympler, wget, fire
#   Building wheel for Pympler (setup.py) ... done
#   Created wheel for Pympler: filename=Pympler-0.9-py3-none-any.whl size=164822 sha256=d657efb7ac7127bafae7226c0108e33271e4e271b75888651b4fc68a16ca3e11
#   Stored in directory: /root/.cache/pip/wheels/03/84/9a/0e7aa69b52bc9dc13ea25679c8d8f1dc11bc5b5289db23d9f3
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=f6f350320044cebc4b4eb62248558fcca00ee460c3671f4d23b671b9e0894dc7
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=2000b0deb4dffce819b165a73355931638738a3c1eb32f55a400f70dfefa7f90
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built Pympler wget fire
# Installing collected packages: wget, Pympler, keras, flatbuffers, websocket-client, tensorflow-estimator, shortuuid, scipy, PyJWT, psutil, onnx, keras-preprocessing, jmespath, importlib-resources, humanfriendly, fire, tf2onnx, scikit-learn, onnxconverter-common, docker, coloredlogs, botocore, skl2onnx, s3transfer, onnxruntime, keras2onnx, tensorboard, onnxmltools, boto3, tensorflow, aimodelshare
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.3.3
#     Uninstalling flatbuffers-23.3.3:
#       Successfully uninstalled flatbuffers-23.3.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 5.12.0
#     Uninstalling importlib-resources-5.12.0:
#       Successfully uninstalled importlib-resources-5.12.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed PyJWT-2.6.0 Pympler-0.9 aimodelshare-0.0.189 boto3-1.26.69 botocore-1.29.82 coloredlogs-15.0.1 docker-5.0.0 fire-0.5.0 flatbuffers-1.12 humanfriendly-10.0 importlib-resources-5.10.0 jmespath-1.0.1 keras-2.9.0 keras-preprocessing-1.1.2 keras2onnx-1.7.0 onnx-1.12.0 onnxconverter-common-1.13.0 onnxmltools-1.11.2 onnxruntime-1.14.1 psutil-5.9.4 s3transfer-0.6.0 scikit-learn-1.2.1 scipy-1.7.0 shortuuid-1.0.11 skl2onnx-1.14.0 tensorboard-2.9.1 tensorflow-2.9.2 tensorflow-estimator-2.9.0 tf2onnx-1.13.0 websocket-client-1.5.1 wget-3.2

# %%
apiurl='https://bb4mkgq8sb.execute-api.us-east-2.amazonaws.com/prod/m'

import aimodelshare as ai
experiment= ai.Experiment(apiurl)

from aimodelshare.aws import set_credentials
set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %% [markdown]
# ### Keras NN

# %%
with tf.device('/device:GPU:0'): #"/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.

  model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(kernel_size=3, filters=32, padding='same', activation='relu', input_shape=(192, 192, 3)),
    tf.keras.layers.Conv2D(kernel_size=1, filters=32, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2),
    tf.keras.layers.Conv2D(kernel_size=3, filters=64, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=1, filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2),
    tf.keras.layers.Conv2D(kernel_size=3, filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=1, filters=128, padding='same', activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(3, activation='softmax')
  ])

  model.compile(
    optimizer="adam", # to use callback set lr arg such as Adam(lr=0.001) instead
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])
  
  # Fitting the CNN to the Training set
  model.fit(X_train, y_train, 
                    epochs = 1, verbose=1,validation_split=.2) #, callbacks=[red_lr]) for callback that automatically adjusts lr
# Out:
# 69/69 [==============================] - 312s 4s/step - loss: 0.7487 - accuracy: 0.6784 - val_loss: 0.4973 - val_accuracy: 0.8106

# %%
model.save("model1.h5", save_format="h5")

# %%
# Reload model and data
import tensorflow as tf
model = tf.keras.models.load_model('model1.h5',compile=False)
model.compile(
    optimizer="adam", # to use callback set lr arg such as Adam(lr=0.001) instead
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 192, 192, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 192, 192, 32)      1056
#
#  max_pooling2d (MaxPooling2D  (None, 96, 96, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 96, 96, 64)        4160
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 128)       16512
#
#  flatten (Flatten)           (None, 294912)            0
#
#  dense (Dense)               (None, 3)                 884739
#
# =================================================================
# Total params: 999,715
# Trainable params: 999,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save preprocessor function (may need to reload function in cell above)
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
# Save tf.keras model (or any tensorflow model) to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x7f8e0691c280> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x7f8e0691c280>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
#Use X_test data to generate model predictions and make leaderboard submission

#Generate and save predictions

#Load preprocessed data
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_test.pkl', 'rb') as file:
    # Call load method to deserialze
    X_test = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)
    
prediction_column_index=model.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8d99cf2af0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 41/41 [==============================] - 57s 1s/step

# %%
# Submit Model 1 to Competition Leaderboard
experiment.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 261
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3340

# %% [markdown]
# ### Applying regularization to weights

# %%
from tensorflow.keras import regularizers

# %%
with tf.device('/device:GPU:0'): #"/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.

  model2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(kernel_size=3, filters=32, padding='same', activation='relu', input_shape=(192, 192, 3), kernel_regularizer=regularizers.L1(l1=0.1)),
    tf.keras.layers.Conv2D(kernel_size=1, filters=32, padding='same', activation='relu', kernel_regularizer=regularizers.L1(l1=0.1)),
    tf.keras.layers.MaxPooling2D(pool_size=2),
    tf.keras.layers.Conv2D(kernel_size=3, filters=64, padding='same', activation='relu', kernel_regularizer=regularizers.L1(l1=0.1)),
    tf.keras.layers.Conv2D(kernel_size=1, filters=64, padding='same', activation='relu', kernel_regularizer=regularizers.L1(l1=0.1)),
    tf.keras.layers.MaxPooling2D(pool_size=2),
    tf.keras.layers.Conv2D(kernel_size=3, filters=128, padding='same', activation='relu', kernel_regularizer=regularizers.L1(l1=0.1)),
    tf.keras.layers.Conv2D(kernel_size=1, filters=128, padding='same', activation='relu', kernel_regularizer=regularizers.L1(l1=0.1)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(3, activation='softmax')
  ])

  model2.compile(
    optimizer="adam", # to use callback set lr arg such as Adam(lr=0.001) instead
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])
  
  # Fitting the CNN to the Training set
  model2.fit(X_train, y_train, 
                    epochs = 1, verbose=1,validation_split=.2) #, callbacks=[red_lr]) for callback that automatically adjusts lr
# Out:
# 69/69 [==============================] - 378s 5s/step - loss: 230.7115 - accuracy: 0.6223 - val_loss: 80.2873 - val_accuracy: 0.6266

# %%
model2.save("model2.h5", save_format="h5")

# %%
# Reload model and data
import tensorflow as tf
model2 = tf.keras.models.load_model('model2.h5',compile=False)
model2.compile(
    optimizer="adam", # to use callback set lr arg such as Adam(lr=0.001) instead
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 192, 192, 32)      896
#
#  conv2d_7 (Conv2D)           (None, 192, 192, 32)      1056
#
#  max_pooling2d_2 (MaxPooling  (None, 96, 96, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 96, 96, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 96, 96, 64)        4160
#
#  max_pooling2d_3 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 48, 48, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 48, 48, 128)       16512
#
#  flatten_1 (Flatten)         (None, 294912)            0
#
#  dense_1 (Dense)             (None, 3)                 884739
#
# =================================================================
# Total params: 999,715
# Trainable params: 999,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save preprocessor function (may need to reload function in cell above)
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
# Save tf.keras model (or any tensorflow model) to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model2 = model_to_onnx(model2, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model2.SerializeToString())
# Out:
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x7f8d99d5cca0> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x7f8d99d5cca0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Layer._handle_weight_regularization.<locals>._loss_for_variable at 0x7f8d9d6c3f70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('name', 'regularizer'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Layer._handle_weight_regularization.<locals>._loss_for_variable at 0x7f8d9d6c3e50> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('name', 'regularizer'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Layer._handle_weight_regularization.<locals>._loss_for_variable at 0x7f8d142c7550> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('name', 'regularizer'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Layer._handle_weight_regularization.<locals>._loss_for_variable at 0x7f8d142c7430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('name', 'regularizer'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Layer._handle_weight_regularization.<locals>._loss_for_variable at 0x7f8d142c71f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('name', 'regularizer'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Layer._handle_weight_regularization.<locals>._loss_for_variable at 0x7f8d142c7160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('name', 'regularizer'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
#Use X_test data to generate model predictions and make leaderboard submission

#Generate and save predictions

#Load preprocessed data
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_test.pkl', 'rb') as file:
    # Call load method to deserialze
    X_test = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)
    
prediction_column_index=model2.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8cdc76c5e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 41/41 [==============================] - 59s 1s/step

# %%
# Submit Model 2 to Competition Leaderboard
experiment.submit_model(model_filepath = "model2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 262
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3340

# %% [markdown]
# ### Transfer Learning with Resnet

# %%
# example of loading a version of the Resnet Model
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Flatten
from tensorflow.keras import backend as K


# load model new input layer shape.

IMG_SHAPE = (192, 192, 3)

# Create base model
base_model = ResNet50(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')

base_model.summary() # Notice unfrozen number of trainable parameters
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 198, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 96, 96, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 96, 96, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 96, 96, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 98, 98, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 48, 48, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 48, 48, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 48, 48, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 48, 48, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 24, 24, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 24, 24, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 24, 24, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 24, 24, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 12, 12, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Next step: Freeze the weights of the model so that they are not trained with you fit the model
# setting the entire model's trainable flag to False will freeze all the layers.

base_model.trainable = False

base_model.summary() # Note the trainable parameters at the bottom now equal zero.
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 198, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 96, 96, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 96, 96, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 96, 96, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 98, 98, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 48, 48, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 48, 48, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 48, 48, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 48, 48, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 24, 24, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 24, 24, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 24, 24, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 24, 24, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 12, 12, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# Add new GAP layer and output layer to frozen layers of original model with adjusted input

# Create new classifier layers (and plug into output of last layer from above model using "model.layers[-1].output")
gap1 = GlobalAveragePooling2D()(base_model.layers[-1].output)
output = Dense(3, activation='softmax')(gap1)
# define new model
model3 = Model(inputs=base_model.inputs, outputs=output)
# summarize
model3.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 198, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 96, 96, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 96, 96, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 96, 96, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 98, 98, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 48, 48, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 48, 48, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 48, 48, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 48, 48, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 24, 24, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 24, 24, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 24, 24, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 24, 24, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 12, 12, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense_2 (Dense)                (None, 3)            6147        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 23,593,859
# Trainable params: 6,147
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# Fit Resnet model with frozen imagenet weights and new input/output layer shapes (outputs have trainable parameters)

with tf.device('/device:GPU:0'): #"/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.

  model3.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['acc']) 

  model3.fit(X_train, y_train,
          epochs = 3, verbose=1,validation_split=.2)
# Out:
# Epoch 1/3
# 69/69 [==============================] - 553s 8s/step - loss: 1.3761 - acc: 0.3426 - val_loss: 1.7502 - val_acc: 0.3388
# Epoch 2/3
# 69/69 [==============================] - 494s 7s/step - loss: 1.3917 - acc: 0.3412 - val_loss: 2.3401 - val_acc: 0.3206
# Epoch 3/3
# 69/69 [==============================] - 540s 8s/step - loss: 1.4091 - acc: 0.3335 - val_loss: 1.2380 - val_acc: 0.3406

# %%
# Save tf.keras model (or any tensorflow model) to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model3 = model_to_onnx(model3, framework='keras',
                          transfer_learning=True,
                          deep_learning=True)

with open("model3.onnx", "wb") as f:
    f.write(onnx_model3.SerializeToString())
# Out:
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x7f8d140be700> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x7f8d140be700>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
#Use X_test data to generate model predictions and make leaderboard submission

#Generate and save predictions

#Load preprocessed data
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_test.pkl', 'rb') as file:
    # Call load method to deserialze
    X_test = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)
    
prediction_column_index=model3.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8cd9381940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 41/41 [==============================] - 236s 6s/step

# %%
# Submit Model 3 to Competition Leaderboard
experiment.submit_model(model_filepath = "model3.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 263
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3340

# %% [markdown]
# # Discuss which models performed better and point out relevant hyper-parameter values for successful models.

# %% [markdown]
# ### Based on the three models I've done, the Keras NN model was the best performing model. For this model, there was only one fully-connected layer that output to 3 categories.

# %% [markdown]
# # After you submit your first three models, describe your best model with your team via your team slack channel. Fit and submit up to three more models after learning from your team.

# %% [markdown]
# ### Resnet with TL, extra layers

# %%
# load model new input layer shape.

IMG_SHAPE = (192, 192, 3)

# Create base model
base_model = ResNet50(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')

base_model.summary() # Notice unfrozen number of trainable parameters
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 198, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 96, 96, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 96, 96, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 96, 96, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 98, 98, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 48, 48, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 48, 48, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 48, 48, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 48, 48, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 24, 24, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 24, 24, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 24, 24, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 24, 24, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 12, 12, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Add new GAP layer and output layer to frozen layers of original model with adjusted input

# Create new classifier layers (and plug into output of last layer from above model using "model.layers[-1].output")
gap1 = GlobalAveragePooling2D()(base_model.layers[-1].output)
class1= Dense(112, activation='relu')(gap1)
class2= Dense(128, activation = 'relu')(class1)
class3= Dense(256, activation = 'relu')(class2)
output = Dense(3, activation='softmax')(class3)

# define new model
model4 = Model(inputs=base_model.inputs, outputs=output)
# summarize
model4.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 198, 198, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 96, 96, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 96, 96, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 96, 96, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 98, 98, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 48, 48, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 48, 48, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 48, 48, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 48, 48, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 48, 48, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 48, 48, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 48, 48, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 48, 48, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 48, 48, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 48, 48, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 48, 48, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 48, 48, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 24, 24, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 24, 24, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 24, 24, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 24, 24, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 24, 24, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 24, 24, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 24, 24, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 24, 24, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 24, 24, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 24, 24, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 24, 24, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 24, 24, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 12, 12, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 12, 12, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 12, 12, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 12, 12, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 6, 6, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 6, 6, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  obalAveragePooling2D)
#
#  dense_3 (Dense)                (None, 112)          229488      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 128)          14464       ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 256)          33024       ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 3)            771         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 23,865,459
# Trainable params: 23,812,339
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Fit Resnet model with frozen imagenet weights and new input/output layer shapes (outputs have trainable parameters)

with tf.device('/device:GPU:0'): #"/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.

  model4.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['acc']) 

  model4.fit(X_train, y_train,
          epochs = 3, verbose=1,validation_split=.2)
# Out:
# Epoch 1/3
# 69/69 [==============================] - 1837s 26s/step - loss: 0.5999 - acc: 0.7783 - val_loss: 1.1842 - val_acc: 0.3388
# Epoch 2/3
# 69/69 [==============================] - 1826s 27s/step - loss: 0.1354 - acc: 0.9599 - val_loss: 3.6464 - val_acc: 0.3388
# Epoch 3/3
# 69/69 [==============================] - 1821s 26s/step - loss: 0.0525 - acc: 0.9854 - val_loss: 3.6959 - val_acc: 0.3388

# %%
# Save tf.keras model (or any tensorflow model) to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model4 = model_to_onnx(model4, framework='keras',
                          transfer_learning=True,
                          deep_learning=True)

with open("model4.onnx", "wb") as f:
    f.write(onnx_model4.SerializeToString())
# Out:
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x7f8cda043d30> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x7f8cda043d30>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
#Use X_test data to generate model predictions and make leaderboard submission

#Generate and save predictions

#Load preprocessed data
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_test.pkl', 'rb') as file:
    # Call load method to deserialze
    X_test = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)
    
prediction_column_index=model4.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8cd9bae5e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 41/41 [==============================] - 221s 5s/step

# %%
# Submit Model 4 to Competition Leaderboard
experiment.submit_model(model_filepath = "model4.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 267
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3340

# %% [markdown]
# ### Inception Model

# %%
# example of loading the Inception model
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Flatten
from tensorflow.keras import backend as K


# load model new input layer shape.

IMG_SHAPE = (192, 192, 3)

# Create the base model from the pre-trained model VGG16
base_model = InceptionV3(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')

base_model.summary() # Notice unfrozen number of trainable parameters
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv2d_12 (Conv2D)             (None, 95, 95, 32)   864         ['input_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 95, 95, 32)  96          ['conv2d_12[0][0]']
#  alization)
#
#  activation (Activation)        (None, 95, 95, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 93, 93, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 93, 93, 32)  96          ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 93, 93, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 93, 93, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 93, 93, 64)  192         ['conv2d_14[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 93, 93, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 46, 46, 64)  0           ['activation_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 46, 46, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 46, 46, 80)  240         ['conv2d_15[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 46, 46, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 44, 44, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 44, 44, 192)  576        ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 44, 44, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 21, 21, 192)  0          ['activation_4[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 21, 21, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_20[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 21, 21, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 21, 21, 48)  144         ['conv2d_18[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 21, 21, 96)  288         ['conv2d_21[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 21, 21, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 21, 21, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 21, 21, 192)  0          ['max_pooling2d_5[0][0]']
#  ing2D)
#
#  conv2d_17 (Conv2D)             (None, 21, 21, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 21, 21, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_17[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_19[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 21, 21, 96)  288         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 21, 21, 32)  96          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 21, 21, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 21, 21, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 21, 21, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 21, 21, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 21, 21, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 21, 21, 48)  144         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 21, 21, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 21, 21, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 21, 21, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_24 (Conv2D)             (None, 21, 21, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 21, 21, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 21, 21, 64)  192         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 21, 21, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 21, 21, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 21, 21, 64)  192         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 21, 21, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 21, 21, 64)  192         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 21, 21, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 21, 21, 48)  144         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 21, 21, 96)  288         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 21, 21, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 21, 21, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_31 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 21, 21, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 21, 21, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 21, 21, 64)  192         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 21, 21, 96)  288         ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 21, 21, 64)  192         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 21, 21, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 21, 21, 64)  192         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 21, 21, 96)  288         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 10, 10, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 10, 10, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 10, 10, 384)  1152       ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 10, 10, 96)  288         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 10, 10, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 10, 10, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 10, 10, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 10, 10, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 10, 10, 128)  384        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 10, 10, 128)  384        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 10, 10, 128)  384        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 10, 10, 128)  384        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 10, 10, 128)  384        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 10, 10, 128)  384        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 10, 10, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_42 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 10, 10, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 10, 10, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 10, 10, 192)  576        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 10, 10, 192)  576        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 10, 10, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 10, 10, 192)  576        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 10, 10, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 10, 10, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 10, 10, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 10, 10, 160)  480        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 10, 10, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 10, 10, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 10, 10, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 10, 10, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_52 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 10, 10, 192)  576        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 10, 10, 192)  576        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 10, 10, 192)  576        ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 10, 10, 192)  576        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 10, 10, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 10, 10, 160)  480        ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 10, 10, 160)  480        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 10, 10, 160)  480        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 10, 10, 160)  480        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 10, 10, 160)  480        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 10, 10, 160)  480        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 10, 10, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_62 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 10, 10, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 10, 10, 192)  576        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 10, 10, 192)  576        ['conv2d_70[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 10, 10, 192)  576        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 10, 10, 768)  0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
# ...
#  mixed8 (Concatenate)           (None, 4, 4, 1280)   0           ['activation_71[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'max_pooling2d_7[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 4, 4, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 4, 4, 448)   1344        ['conv2d_92[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 4, 4, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 4, 4, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 4, 4, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_89[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 4, 4, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_88 (Conv2D)             (None, 4, 4, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  conv2d_96 (Conv2D)             (None, 4, 4, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 4, 4, 320)   960         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 4, 4, 192)   576         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 4, 4, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 4, 4, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 4, 4, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 4, 4, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 4, 4, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 4, 4, 448)   1344        ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 4, 4, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 4, 4, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 4, 4, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_98[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_102[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 4, 4, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_97 (Conv2D)             (None, 4, 4, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_100[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_103[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_104[0][0]']
#  ormalization)
#
#  conv2d_105 (Conv2D)            (None, 4, 4, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 4, 4, 320)   960         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 4, 4, 192)   576         ['conv2d_105[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 4, 4, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 4, 4, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 4, 4, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 4, 4, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# Next step: Freeze the weights of the model so that they are not trained with you fit the model
# setting the entire model's trainable flag to False will freeze all the layers.

base_model.trainable = False

base_model.summary() # Note the trainable parameters at the bottom now equal zero.
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv2d_12 (Conv2D)             (None, 95, 95, 32)   864         ['input_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 95, 95, 32)  96          ['conv2d_12[0][0]']
#  alization)
#
#  activation (Activation)        (None, 95, 95, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 93, 93, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 93, 93, 32)  96          ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 93, 93, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 93, 93, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 93, 93, 64)  192         ['conv2d_14[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 93, 93, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 46, 46, 64)  0           ['activation_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 46, 46, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 46, 46, 80)  240         ['conv2d_15[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 46, 46, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 44, 44, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 44, 44, 192)  576        ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 44, 44, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 21, 21, 192)  0          ['activation_4[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 21, 21, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_20[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 21, 21, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 21, 21, 48)  144         ['conv2d_18[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 21, 21, 96)  288         ['conv2d_21[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 21, 21, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 21, 21, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 21, 21, 192)  0          ['max_pooling2d_5[0][0]']
#  ing2D)
#
#  conv2d_17 (Conv2D)             (None, 21, 21, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 21, 21, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_17[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_19[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 21, 21, 96)  288         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 21, 21, 32)  96          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 21, 21, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 21, 21, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 21, 21, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 21, 21, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 21, 21, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 21, 21, 48)  144         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 21, 21, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 21, 21, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 21, 21, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_24 (Conv2D)             (None, 21, 21, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 21, 21, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 21, 21, 64)  192         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 21, 21, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 21, 21, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 21, 21, 64)  192         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 21, 21, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 21, 21, 64)  192         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 21, 21, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 21, 21, 48)  144         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 21, 21, 96)  288         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 21, 21, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 21, 21, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_31 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 21, 21, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 21, 21, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 21, 21, 64)  192         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 21, 21, 96)  288         ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 21, 21, 64)  192         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 21, 21, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 21, 21, 64)  192         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 21, 21, 96)  288         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 10, 10, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 10, 10, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 10, 10, 384)  1152       ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 10, 10, 96)  288         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 10, 10, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 10, 10, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 10, 10, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 10, 10, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 10, 10, 128)  384        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 10, 10, 128)  384        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 10, 10, 128)  384        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 10, 10, 128)  384        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 10, 10, 128)  384        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 10, 10, 128)  384        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 10, 10, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_42 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 10, 10, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 10, 10, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 10, 10, 192)  576        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 10, 10, 192)  576        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 10, 10, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 10, 10, 192)  576        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 10, 10, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 10, 10, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 10, 10, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 10, 10, 160)  480        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 10, 10, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 10, 10, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 10, 10, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 10, 10, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_52 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 10, 10, 192)  576        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 10, 10, 192)  576        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 10, 10, 192)  576        ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 10, 10, 192)  576        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 10, 10, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 10, 10, 160)  480        ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 10, 10, 160)  480        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 10, 10, 160)  480        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 10, 10, 160)  480        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 10, 10, 160)  480        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 10, 10, 160)  480        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 10, 10, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_62 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 10, 10, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 10, 10, 192)  576        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 10, 10, 192)  576        ['conv2d_70[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 10, 10, 192)  576        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 10, 10, 768)  0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 4, 4, 1280)   0           ['activation_71[0][0]',
#                                                                   'activation_75[0][0]',
#                                                                   'max_pooling2d_7[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 4, 4, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 4, 4, 448)   1344        ['conv2d_92[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 4, 4, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 4, 4, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 4, 4, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_89[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 4, 4, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_88 (Conv2D)             (None, 4, 4, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  conv2d_96 (Conv2D)             (None, 4, 4, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 4, 4, 320)   960         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 4, 4, 192)   576         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 4, 4, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 4, 4, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 4, 4, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 4, 4, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 4, 4, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 4, 4, 448)   1344        ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 4, 4, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 4, 4, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 4, 4, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_98[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_102[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 4, 4, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_97 (Conv2D)             (None, 4, 4, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_100[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_103[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_104[0][0]']
#  ormalization)
#
#  conv2d_105 (Conv2D)            (None, 4, 4, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 4, 4, 320)   960         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 4, 4, 192)   576         ['conv2d_105[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 4, 4, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 4, 4, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 4, 4, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 4, 4, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# Add new GAP layer and output layer to frozen layers of original model with adjusted input
gap1 = GlobalAveragePooling2D()(base_model.layers[-1].output)

class1= Dense(112, activation='relu')(gap1)
class2= Dense(256, activation = 'relu')(class1)
output = Dense(3, activation='softmax')(class2)

# define new model
model5 = Model(inputs=base_model.inputs, outputs=output)
# summarize
model5.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 192, 192, 3  0           []
#                                 )]
#
#  conv2d_12 (Conv2D)             (None, 95, 95, 32)   864         ['input_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 95, 95, 32)  96          ['conv2d_12[0][0]']
#  alization)
#
#  activation (Activation)        (None, 95, 95, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 93, 93, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 93, 93, 32)  96          ['conv2d_13[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 93, 93, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 93, 93, 64)   18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 93, 93, 64)  192         ['conv2d_14[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 93, 93, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 46, 46, 64)  0           ['activation_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 46, 46, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 46, 46, 80)  240         ['conv2d_15[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 46, 46, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 44, 44, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 44, 44, 192)  576        ['conv2d_16[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 44, 44, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 21, 21, 192)  0          ['activation_4[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 21, 21, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_20[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 21, 21, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 21, 21, 48)  144         ['conv2d_18[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 21, 21, 96)  288         ['conv2d_21[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 21, 21, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 21, 21, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 21, 21, 192)  0          ['max_pooling2d_5[0][0]']
#  ing2D)
#
#  conv2d_17 (Conv2D)             (None, 21, 21, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 21, 21, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_17[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 21, 21, 64)  192         ['conv2d_19[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 21, 21, 96)  288         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 21, 21, 32)  96          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 21, 21, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 21, 21, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 21, 21, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 21, 21, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 21, 21, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 21, 21, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 21, 21, 48)  144         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 21, 21, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 21, 21, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 21, 21, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_24 (Conv2D)             (None, 21, 21, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 21, 21, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 21, 21, 64)  192         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 21, 21, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 21, 21, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 21, 21, 64)  192         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 21, 21, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 21, 21, 64)  192         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 21, 21, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 21, 21, 48)  144         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 21, 21, 96)  288         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 21, 21, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 21, 21, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_31 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 21, 21, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 21, 21, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 21, 21, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 21, 21, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 21, 21, 64)  192         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 21, 21, 96)  288         ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 21, 21, 64)  192         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 21, 21, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 21, 21, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 21, 21, 64)  192         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 21, 21, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 21, 21, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 21, 21, 96)  288         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 21, 21, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 10, 10, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 10, 10, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 10, 10, 384)  1152       ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 10, 10, 96)  288         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 10, 10, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 10, 10, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 10, 10, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 10, 10, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 10, 10, 128)  384        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 10, 10, 128)  384        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 10, 10, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 10, 10, 128)  384        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 10, 10, 128)  384        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 10, 10, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 10, 10, 128)  384        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 10, 10, 128)  384        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 10, 10, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 10, 10, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_42 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 10, 10, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 10, 10, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 10, 10, 192)  576        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 10, 10, 192)  576        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 10, 10, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 10, 10, 192)  576        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 10, 10, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 10, 10, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 10, 10, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 10, 10, 160)  480        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 10, 10, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 10, 10, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 10, 10, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 10, 10, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_52 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 10, 10, 192)  576        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 10, 10, 192)  576        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 10, 10, 192)  576        ['conv2d_60[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 10, 10, 192)  576        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 10, 10, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 10, 10, 160)  480        ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 10, 10, 160)  480        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 10, 10, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 10, 10, 160)  480        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 10, 10, 160)  480        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 10, 10, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 10, 10, 160)  480        ['conv2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 10, 10, 160)  480        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 10, 10, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 10, 10, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_62 (Conv2D)             (None, 10, 10, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 10, 10, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 10, 10, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 10, 10, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 10, 10, 192)  576        ['conv2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 10, 10, 192)  576        ['conv2d_70[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 10, 10, 192)  576        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 10, 10, 192)  0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 10, 10, 768)  0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
# ...
#
#  conv2d_89 (Conv2D)             (None, 4, 4, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 4, 4, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_89[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 4, 4, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_88 (Conv2D)             (None, 4, 4, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  conv2d_96 (Conv2D)             (None, 4, 4, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 4, 4, 320)   960         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 4, 4, 192)   576         ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 4, 4, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 4, 4, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 4, 4, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 4, 4, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 4, 4, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 4, 4, 448)   1344        ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 4, 4, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 4, 4, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 4, 4, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_98[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_102[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 4, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 4, 4, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 4, 4, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_97 (Conv2D)             (None, 4, 4, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_99[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_100[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_103[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 4, 4, 384)   1152        ['conv2d_104[0][0]']
#  ormalization)
#
#  conv2d_105 (Conv2D)            (None, 4, 4, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 4, 4, 320)   960         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 4, 4, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 4, 4, 192)   576         ['conv2d_105[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 4, 4, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 4, 4, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 4, 4, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 4, 4, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dense_7 (Dense)                (None, 112)          229488      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 256)          28928       ['dense_7[0][0]']
#
#  dense_9 (Dense)                (None, 3)            771         ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 22,061,971
# Trainable params: 259,187
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# Fit Inception model with frozen imagenet weights and new input/output layer shapes (outputs have trainable parameters)

with tf.device('/device:GPU:0'): #"/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.

  model5.compile(
    optimizer='adam',
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])

  model5.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc']) 

  model5.fit(X_train, y_train,
          epochs = 1, verbose=1,validation_split=.2)
# Out:
# 69/69 [==============================] - 334s 5s/step - loss: 0.6214 - acc: 0.7217 - val_loss: 0.4793 - val_acc: 0.7960

# %%
# Save tf.keras model (or any tensorflow model) to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model5 = model_to_onnx(model5, framework='keras',
                          transfer_learning=True,
                          deep_learning=True)

with open("model5.onnx", "wb") as f:
    f.write(onnx_model4.SerializeToString())
# Out:
# WARNING: AutoGraph could not transform <function trace_model_call.<locals>._wrapped_model at 0x7f8cd71d7160> and will run it as-is.
# Cause: Unable to locate the source code of <function trace_model_call.<locals>._wrapped_model at 0x7f8cd71d7160>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
#Use X_test data to generate model predictions and make leaderboard submission

#Generate and save predictions

#Load preprocessed data
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_test.pkl', 'rb') as file:
    # Call load method to deserialze
    X_test = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)
    
prediction_column_index=model5.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f8cd47799d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: closure mismatch, requested ('self', 'step_function'), but source function had ()
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 41/41 [==============================] - 142s 3s/step

# %%
# Submit Model 5 to Competition Leaderboard
experiment.submit_model(model_filepath = "model5.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 268
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3340

# %% [markdown]
# ### Keras NN, with more fully-connected layers

# %%
with tf.device('/device:GPU:0'): #"/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.

  model6 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(kernel_size=3, filters=32, padding='same', activation='relu', input_shape=(192, 192, 3)),
    tf.keras.layers.Conv2D(kernel_size=1, filters=32, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2),
    tf.keras.layers.Conv2D(kernel_size=3, filters=64, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=1, filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=2),
    tf.keras.layers.Conv2D(kernel_size=3, filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=1, filters=128, padding='same', activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(256, activation = 'relu'),
    tf.keras.layers.Dense(128, activation = 'relu'),
    tf.keras.layers.Dense(3, activation='softmax')
  ])

  model6.compile(
    optimizer="adam", # to use callback set lr arg such as Adam(lr=0.001) instead
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])
  
  # Fitting the CNN to the Training set
  model6.fit(X_train, y_train, 
                    epochs = 1, verbose=1,validation_split=.2) #, callbacks=[red_lr]) for callback that automatically adjusts lr
# Out:
# 69/69 [==============================] - 450s 6s/step - loss: 0.7177 - accuracy: 0.6647 - val_loss: 0.4786 - val_accuracy: 0.8033

# %%
model6.save("model6.h5", save_format="h5")

# %%
# Reload model and data
import tensorflow as tf
model6 = tf.keras.models.load_model('model6.h5',compile=False)
model6.compile(
    optimizer="adam", # to use callback set lr arg such as Adam(lr=0.001) instead
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])
model6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 192, 192, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 192, 192, 32)      1056
#
#  max_pooling2d (MaxPooling2D  (None, 96, 96, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 96, 96, 64)        4160
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 128)       16512
#
#  flatten (Flatten)           (None, 294912)            0
#
#  dense (Dense)               (None, 128)               37748864
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 37,930,147
# Trainable params: 37,930,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save preprocessor function (may need to reload function in cell above)
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
# Save tf.keras model (or any tensorflow model) to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model6 = model_to_onnx(model6, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model6.onnx", "wb") as f:
    f.write(onnx_model6.SerializeToString())

# %%
#Use X_test data to generate model predictions and make leaderboard submission

#Generate and save predictions

#Load preprocessed data
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_test.pkl', 'rb') as file:
    # Call load method to deserialze
    X_test = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)
    
prediction_column_index=model6.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]
# Out:
# 41/41 [==============================] - 65s 2s/step

# %%
# Submit Model 6 to Competition Leaderboard
experiment.submit_model(model_filepath = "model6.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 275
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3340

# %% [markdown]
# # Try to use augmented data to rerun at least one model and submit it to the leaderboard.

# %% [markdown]
# ### Using augmented data on Keras Model

# %%
# Flipping images horizontally 
datagen = ImageDataGenerator(horizontal_flip=True, vertical_flip=False)

# %%
aug_iter = datagen.flow(X_train, batch_size=1)

# %%
model7 = model6.fit(datagen.flow(X_train, y_train, batch_size = 1), epochs = 1)
# Out:
# 2741/2741 [==============================] - 676s 247ms/step - loss: 0.6556 - accuracy: 0.7238

# %%
model6.save("model6.h5", save_format="h5")

# %%
# Reload model and data
import tensorflow as tf
model7 = tf.keras.models.load_model('model6.h5',compile=False)
model7.compile(
    optimizer="adam", # to use callback set lr arg such as Adam(lr=0.001) instead
    loss= 'categorical_crossentropy',
    metrics=['accuracy'])
model7.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 192, 192, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 192, 192, 32)      1056
#
#  max_pooling2d (MaxPooling2D  (None, 96, 96, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 96, 96, 64)        4160
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 128)       16512
#
#  flatten (Flatten)           (None, 294912)            0
#
#  dense (Dense)               (None, 128)               37748864
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 37,930,147
# Trainable params: 37,930,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save preprocessor function (may need to reload function in cell above)
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
# Save tf.keras model (or any tensorflow model) to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model7 = model_to_onnx(model7, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model7.onnx", "wb") as f:
    f.write(onnx_model7.SerializeToString())

# %%
#Use X_test data to generate model predictions and make leaderboard submission

#Generate and save predictions

#Load preprocessed data
#If you run out of Colab memory restart runtime, reload data and try again
import pickle
  
# Open the file in binary mode
with open('X_test.pkl', 'rb') as file:
    # Call load method to deserialze
    X_test = pickle.load(file)

# Open the file in binary mode
with open('y_train.pkl', 'rb') as file:
    # Call load method to deserialze
    y_train = pickle.load(file)
    
prediction_column_index=model7.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]
# Out:
# 41/41 [==============================] - 33s 765ms/step

# %%
# Submit Model 7 to Competition Leaderboard
experiment.submit_model(model_filepath = "model7.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /usr/local/lib/python3.9/dist-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 343
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3340

# %% [markdown]
# ##### After augmenting data, the model didn't seem to perform better than my best model.

# %% [markdown]
# # Discuss results. Discuss which models you tried and which models performed better and point out relevant hyper-parameter values for successful models.

# %% [markdown]
# ### For COVID radiography data, the models that were tested were Keras Neural Networks, Resnet, and the Inception Model. Of all variations of these models, the best performing model was the Keras Neural Network with additional fully-connected layers. For this model, there are 6 convolutional layers, followed by 3 hidden layers, which outputs to 3 categories: COVID, Normal, Pneumonia.
